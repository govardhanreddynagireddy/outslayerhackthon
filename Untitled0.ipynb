# %%
import torch

# Check if GPU is avaiālable
if torch.cuda.is_available():
    print("GPU is available!")
    print("Device name:", torch.cuda.get_device_name(0))
else:
    print("GPU is NOT available.")
# Out:
# GPU is available!
# Device name: Tesla T4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torch torchvision torchaudio
# !pip install matplotlib
# !pip install tqdm

# %%
# !ls "/content/drive/MyDrive/"
# Out:
# 'Advertising Dataset.gsheet'	   hackthon
# 'BFT & DFT - 4.gdoc'		  'Heap Sort - 3 (1).gdoc'
# 'B-Tree - 2 (1).gdoc'		  'Heap Sort - 3.gdoc'
# 'B-Tree - 2 (2).gdoc'		  'Iris dataset (1).gsheet'
# 'B-Tree - 2.gdoc'		  'Iris dataset.gsheet'
#  Classroom			  'quick sort (1).gdoc'
# 'Colab Notebooks'		  'quick sort (2).gdoc'
#  C_Programming_L_lab_record.gdoc  'quick sort (3).gdoc'
# 'dataset (1).gsheet'		  'quick sort.gdoc'
#  dataset.gsheet			  'Rabin carp (1).gdoc'
# 'diabetes (1).gsheet'		  'Rabin carp.gdoc'
#  diabetes.gsheet		   Salary_Data.gsheet
# 'exp4 249xa33123.ipynb'		   Social_Network_Ads.gsheet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls -l "/content/drive/MyDrive/"
# Out:
# total 31
# -rw------- 1 root root  177 Jan 20 09:15 'Advertising Dataset.gsheet'
# -rw------- 1 root root  177 Oct  4 17:23 'BFT & DFT - 4.gdoc'
# -rw------- 1 root root  177 Jul 28  2025 'B-Tree - 2 (1).gdoc'
# -rw------- 1 root root  177 Jul 28  2025 'B-Tree - 2 (2).gdoc'
# -rw------- 1 root root  177 Jul 28  2025 'B-Tree - 2.gdoc'
# drwx------ 2 root root 4096 Sep 20  2024  Classroom
# drwx------ 2 root root 4096 Jan 12 03:41 'Colab Notebooks'
# -rw------- 1 root root  177 Oct 10  2024  C_Programming_L_lab_record.gdoc
# -rw------- 1 root root  177 Jan  6 09:18 'dataset (1).gsheet'
# -rw------- 1 root root  177 Jan  6 09:24  dataset.gsheet
# -rw------- 1 root root  177 Jan 27 09:01 'diabetes (1).gsheet'
# -rw------- 1 root root  177 Feb 10 06:47  diabetes.gsheet
# -rw------- 1 root root 7612 Jan 27 04:12 'exp4 249xa33123.ipynb'
# drwx------ 2 root root 4096 Feb 25 06:11  hackthon
# -rw------- 1 root root  177 Oct  4 06:05 'Heap Sort - 3 (1).gdoc'
# ...

# %%
# !ls "/content/drive/MyDrive/hackthon"
# Out:
# Offroad_Segmentation_Scripts.zip     Offroad_Segmentation_Training_Dataset.zip
# Offroad_Segmentation_testImages.zip

# %%
# %cd "/content/drive/MyDrive/hackthon"
# !ls
# Out:
# /content/drive/MyDrive/hackthon
# Offroad_Segmentation_Scripts.zip     Offroad_Segmentation_Training_Dataset.zip
# Offroad_Segmentation_testImages.zip

# %%
import os

# Create main working folder
os.makedirs("/content/hackathon", exist_ok=True)

print("Main hackathon folder created!")
# Out:
# Main hackathon folder created!

# %%
# !pip install torch torchvision
# !pip install segmentation-models-pytorch albumentations opencv-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 6.0 MB/s eta 0:00:00
# ...

# %%
# !ls /content/hackathon

# %%
# !ls /content/hackathon/Offroad_Segmentation_Scripts
# Out:
# ls: cannot access '/content/hackathon/Offroad_Segmentation_Scripts': No such file or directory

# %%
# !ls -R /content/hackathon
# Out:
# /content/hackathon:

# %%
import zipfile
import os

# Create folder if not exists
os.makedirs("/content/hackathon", exist_ok=True)

zip_files = [
    "/content/drive/MyDrive/hackthon/Offroad_Segmentation_Scripts.zip",
    "/content/drive/MyDrive/hackthon/Offroad_Segmentation_Training_Dataset.zip",
    "/content/drive/MyDrive/hackthon/Offroad_Segmentation_testImages.zip"
]

for zip_path in zip_files:
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall("/content/hackathon")

print("✅ All files extracted successfully!")
# Out:
# ✅ All files extracted successfully!

# %%
# !ls -R /content/hackathon
# Out:
# /content/hackathon:
# ENV_SETUP			       test_segmentation.py
# Offroad_Segmentation_testImages        train_segmentation.py
# Offroad_Segmentation_Training_Dataset  visualize.py
#
# /content/hackathon/ENV_SETUP:
# create_env.bat	install_packages.bat  setup_env.bat
#
# /content/hackathon/Offroad_Segmentation_testImages:
# Color_Images  Segmentation
#
# /content/hackathon/Offroad_Segmentation_testImages/Color_Images:
# 0000060.png  0000227.png  0000394.png  0000561.png  0000728.png  0000895.png
# 0000061.png  0000228.png  0000395.png  0000562.png  0000729.png  0000896.png
# 0000062.png  0000229.png  0000396.png  0000563.png  0000730.png  0000897.png
# 0000063.png  0000230.png  0000397.png  0000564.png  0000731.png  0000898.png
# 0000064.png  0000231.png  0000398.png  0000565.png  0000732.png  0000899.png
# 0000065.png  0000232.png  0000399.png  0000566.png  0000733.png  0000900.png
# 0000066.png  0000233.png  0000400.png  0000567.png  0000734.png  0000901.png
# ...

# %%
# !ls /content/hackathon
# Out:
# ENV_SETUP			       test_segmentation.py
# Offroad_Segmentation_testImages        train_segmentation.py
# Offroad_Segmentation_Training_Dataset  visualize.py

# %%
file_path = "/content/hackathon/train_segmentation.py"

with open(file_path, "r") as f:
    content = f.read()

content = content.replace(
    "os.path.join(script_dir, '..', 'Offroad_Segmentation_Training_Dataset', 'train')",
    "os.path.join(script_dir, 'Offroad_Segmentation_Training_Dataset', 'train')"
)

content = content.replace(
    "os.path.join(script_dir, '..', 'Offroad_Segmentation_Training_Dataset', 'val')",
    "os.path.join(script_dir, 'Offroad_Segmentation_Training_Dataset', 'val')"
)

with open(file_path, "w") as f:
    f.write(content)

print("✅ Dataset path fixed correctly!")
# Out:
# ✅ Dataset path fixed correctly!

# %%
# %cd /content/hackathon
# !python train_segmentation.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Evaluating:  12% 170/1429 [00:18<02:10,  9.64batch/s]
# Evaluating:  12% 171/1429 [00:18<02:11,  9.55batch/s]
# Evaluating:  12% 173/1429 [00:18<02:10,  9.60batch/s]
# Evaluating:  12% 175/1429 [00:19<02:08,  9.76batch/s]
# Evaluating:  12% 176/1429 [00:19<02:11,  9.53batch/s]
# Evaluating:  12% 177/1429 [00:19<02:10,  9.63batch/s]
# Evaluating:  12% 178/1429 [00:19<02:09,  9.69batch/s]
# Evaluating:  13% 179/1429 [00:19<02:13,  9.34batch/s]
# Evaluating:  13% 180/1429 [00:19<02:14,  9.30batch/s]
# Evaluating:  13% 182/1429 [00:19<02:09,  9.63batch/s]
# Evaluating:  13% 183/1429 [00:19<02:12,  9.42batch/s]
# Evaluating:  13% 185/1429 [00:20<02:08,  9.68batch/s]
# Evaluating:  13% 186/1429 [00:20<02:10,  9.54batch/s]
# Evaluating:  13% 188/1429 [00:20<02:07,  9.70batch/s]
# Evaluating:  13% 189/1429 [00:20<02:08,  9.64batch/s]
# Evaluating:  13% 190/1429 [00:20<02:09,  9.55batch/s]
# ...
